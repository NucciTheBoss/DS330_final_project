# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
df = pd.read_csv('/content/drive/My Drive/spotify_data/sampled_spotify.csv')
# Out:
# Mounted at /content/drive

# %%
df.head(100)
# Out:
#     Unnamed: 0  Unnamed: 0.1                                track_id  \
# 0       346473        346473  t_0789d858-e112-4040-b13c-4407afb6d976
# 1       585290        585290  t_7ab807c3-f28f-44f8-94a4-08b6218fc2b9
# 2       120969        120969  t_f09bb77d-b77e-46c4-b7f7-20b67729be24
# 3       190926        190926  t_40db5822-be31-4553-8484-93efbbe2dda6
# 4       272318        272318  t_81f2b320-eb4a-4fa5-922f-46225794729d
# ..         ...           ...                                     ...
# 95      421297        421297  t_528c8395-7b93-4cbc-b4ba-bed58483353e
# 96      626130        626130  t_652a5983-35b6-4cfb-883a-d5f47ce9e3bf
# 97      569047        569047  t_54074f16-42c1-4fb7-bf22-362193bfd249
# 98       86092         86092  t_a36608d2-93d9-4ef0-9dc4-7f5676f717f5
# 99        9826          9826  t_f521e4be-fc1d-48f5-aad7-3352c04c3a92
#
#     hour_of_day        date    duration  release_year  us_popularity_estimate  \
# ...

# %% [markdown]
# Take three days before each event and three days after. Look at quantatative change in the beat, danceability, and energy. Maybe add some cool colors.

# %%
df_firstevent = df[(df['date'] >= '2018-07-15') & (df['date'] <= '2018-07-17')]
df_secondevent = df[(df['date'] >= '2018-07-25') & (df['date'] <= '2018-07-27')]
df_thirdevent = df[(df['date'] >= '2018-08-05') & (df['date'] <= '2018-08-07')]
df_fourthevent = df[(df['date'] >= '2018-09-10') & (df['date'] <= '2018-09-12')]

# %%
grouped_df = df_firstevent.groupby("date")
mean_df1 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df1 = mean_df1.reset_index()
mean_df1['Event'] = "Jeff Bezos Wealth"
mean_df1['Date_Order'] = "0"
for i in range(len(mean_df1)):
  if mean_df1['date'][i] == "2018-07-15":
    mean_df1["Date_Order"][i] =1
  elif mean_df1['date'][i] == "2018-07-16":
    mean_df1["Date_Order"][i] =2
  elif mean_df1['date'][i] == "2018-07-17":
    mean_df1["Date_Order"][i] =3


print(mean_df1)

grouped_df = df_secondevent.groupby("date")
mean_df2 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df2 = mean_df2.reset_index()
mean_df2['Event'] = "Facebook Sell Off"
mean_df2['Date_Order'] = "0"
for i in range(len(mean_df2)):
  if mean_df2['date'][i] == "2018-07-25":
    mean_df2["Date_Order"][i] =1
  elif mean_df2['date'][i] == "2018-07-26":
    mean_df2["Date_Order"][i] =2
  elif mean_df2['date'][i] == "2018-07-27":
    mean_df2["Date_Order"][i] =3

print(mean_df2)

grouped_df = df_thirdevent.groupby("date")
mean_df3 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df3 = mean_df3.reset_index()
mean_df3['Event'] = "Saudi Arabia and Canadian Diplomats"
mean_df3['Date_Order'] = "0"

for i in range(len(mean_df3)):
  if mean_df3['date'][i] == "2018-08-05":
    mean_df3["Date_Order"][i] =1
  elif mean_df3['date'][i] == "2018-08-06":
    mean_df3["Date_Order"][i] =2
  elif mean_df3['date'][i] == "2018-08-07":
    mean_df3["Date_Order"][i] =3

print(mean_df3)

grouped_df = df_fourthevent.groupby("date")
mean_df4 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df4 = mean_df4.reset_index()
mean_df4['Event'] = "Hurricane Florence"
mean_df4['Date_Order'] = "0"

for i in range(len(mean_df4)):
  if mean_df4['date'][i] == "2018-09-10":
    mean_df4["Date_Order"][i] =1
  elif mean_df4['date'][i] == "2018-09-11":
    mean_df4["Date_Order"][i] =2
  elif mean_df4['date'][i] == "2018-09-12":
    mean_df4["Date_Order"][i] =3

print(mean_df4)


result = pd.concat([mean_df1, mean_df2,mean_df3,mean_df4], axis=0)
result
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# ...

# %%
fig1 = px.scatter(result, x=result["beat_strength"], y=result["date"], color="Event", symbol="Event")
fig1.update_layout( title={
        'text': "Beat Strength",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig1.update_traces(marker=dict(size=10,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.scatter(result, x=result["danceability"], y=result["date"], color="Event", symbol="Event")
fig2.update_layout( title={
        'text': "Danceability",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig2.update_traces(marker=dict(size=10,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.scatter(result, x=result["energy"], y=result["date"], color="Event", symbol="Event")
fig3.update_layout( title={
        'text': "Energy",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig3.update_traces(marker=dict(size=10,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4 = px.scatter_3d(result, x=result["beat_strength"], y=result["danceability"], z=result["energy"],
                    color='Event', symbol='date')

fig4.update_layout( title={
        'text': "3-D Interactions of Beat, Danceability, and Energy",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))


fig4.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig4.update_layout(scene = dict(xaxis = dict(nticks=4, range=[.51,.55],),yaxis = dict(nticks=4, range=[.65,.67],),zaxis = dict(nticks=4, range=[.62,.64],)))





fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grouped_df = df_firstevent.groupby("hour_of_day")
mean_df1 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df1 = mean_df1.reset_index()
mean_df1['Event'] = "Jeff Bezos Wealth"

grouped_df = df_secondevent.groupby("hour_of_day")
mean_df2 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df2 = mean_df2.reset_index()
mean_df2['Event'] = "Facebook Sell Off"

grouped_df = df_thirdevent.groupby("hour_of_day")
mean_df3 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df3 = mean_df3.reset_index()
mean_df3['Event'] = "Saudi Arabia and Canadian Diplomats"

grouped_df = df_fourthevent.groupby("hour_of_day")
mean_df4 = grouped_df["beat_strength","danceability","energy"].mean()
mean_df4 = mean_df4.reset_index()
mean_df4['Event'] = "Hurricane Florence"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
mean_df1
# Out:
#     hour_of_day  beat_strength  danceability    energy              Event
# 0             0       0.551372      0.670257  0.612025  Jeff Bezos Wealth
# 1             1       0.552114      0.670866  0.612834  Jeff Bezos Wealth
# 2             2       0.551224      0.669352  0.609252  Jeff Bezos Wealth
# 3             3       0.546617      0.667059  0.615978  Jeff Bezos Wealth
# 4             4       0.547728      0.667263  0.621465  Jeff Bezos Wealth
# 5             5       0.539835      0.661137  0.630077  Jeff Bezos Wealth
# 6             6       0.535627      0.658549  0.632683  Jeff Bezos Wealth
# 7             7       0.534505      0.658530  0.632729  Jeff Bezos Wealth
# 8             8       0.533706      0.656916  0.630152  Jeff Bezos Wealth
# 9             9       0.536996      0.659246  0.628067  Jeff Bezos Wealth
# 10           10       0.537330      0.659815  0.628575  Jeff Bezos Wealth
# 11           11       0.541819      0.664189  0.628561  Jeff Bezos Wealth
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(
    x=mean_df1["hour_of_day"],
    y=mean_df1["beat_strength"],
    name="Jeff Bezos Wealth",
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=mean_df2["hour_of_day"],
    y=mean_df2["beat_strength"],
    name="Facebook Sell Off",
    marker_color='goldenrod'
))

fig.add_trace(go.Bar(
    x=mean_df3["hour_of_day"],
    y=mean_df3["beat_strength"],
    name="Saudi Arabia and Canadian Diplomats",
    marker_color='magenta'
))

fig.add_trace(go.Bar(
    x=mean_df4["hour_of_day"],
    y=mean_df4["beat_strength"],
    name="Hurricane Florence",
    marker_color='blue'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.update_layout( title={
        'text': "Hourly Beat_Strength",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(
    x=mean_df1["hour_of_day"],
    y=mean_df1["danceability"],
    name="Jeff Bezos Wealth",
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=mean_df2["hour_of_day"],
    y=mean_df2["danceability"],
    name="Facebook Sell Off",
    marker_color='goldenrod'
))

fig.add_trace(go.Bar(
    x=mean_df3["hour_of_day"],
    y=mean_df3["danceability"],
    name="Saudi Arabia and Canadian Diplomats",
    marker_color='magenta'
))

fig.add_trace(go.Bar(
    x=mean_df4["hour_of_day"],
    y=mean_df4["danceability"],
    name="Hurricane Florence",
    marker_color='blue'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.update_layout( title={
        'text': "Hourly Danceability",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(
    x=mean_df1["hour_of_day"],
    y=mean_df1["energy"],
    name="Jeff Bezos Wealth",
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=mean_df2["hour_of_day"],
    y=mean_df2["energy"],
    name="Facebook Sell Off",
    marker_color='goldenrod'
))

fig.add_trace(go.Bar(
    x=mean_df3["hour_of_day"],
    y=mean_df3["energy"],
    name="Saudi Arabia and Canadian Diplomats",
    marker_color='magenta'
))

fig.add_trace(go.Bar(
    x=mean_df4["hour_of_day"],
    y=mean_df4["energy"],
    name="Hurricane Florence",
    marker_color='blue'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.update_layout( title={
        'text': "Hourly Energy",
        'y':.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'},
        font=dict(
            size=12,
        ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
result = pd.concat([mean_df1, mean_df2,mean_df3,mean_df4], axis=0)
result
# Out:
#     hour_of_day  beat_strength  danceability    energy               Event
# 0             0       0.551372      0.670257  0.612025   Jeff Bezos Wealth
# 1             1       0.552114      0.670866  0.612834   Jeff Bezos Wealth
# 2             2       0.551224      0.669352  0.609252   Jeff Bezos Wealth
# 3             3       0.546617      0.667059  0.615978   Jeff Bezos Wealth
# 4             4       0.547728      0.667263  0.621465   Jeff Bezos Wealth
# ..          ...            ...           ...       ...                 ...
# 19           19       0.539121      0.661431  0.627582  Hurricane Florence
# 20           20       0.539774      0.660736  0.623232  Hurricane Florence
# 21           21       0.536532      0.656684  0.617181  Hurricane Florence
# 22           22       0.533531      0.653761  0.613450  Hurricane Florence
# 23           23       0.528791      0.649118  0.610553  Hurricane Florence
#
# [96 rows x 5 columns]

# %%
grouped_df_total = df.groupby("hour_of_day")
mean_df5 = grouped_df_total["beat_strength","danceability","energy"].mean()
mean_df5 = mean_df5.reset_index()
mean_df5['Event'] = "Total Averages"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
result_tab = pd.concat([mean_df1, mean_df2,mean_df3,mean_df4,mean_df5], axis=0)
result_tab
# Out:
#     hour_of_day  beat_strength  danceability    energy              Event
# 0             0       0.551372      0.670257  0.612025  Jeff Bezos Wealth
# 1             1       0.552114      0.670866  0.612834  Jeff Bezos Wealth
# 2             2       0.551224      0.669352  0.609252  Jeff Bezos Wealth
# 3             3       0.546617      0.667059  0.615978  Jeff Bezos Wealth
# 4             4       0.547728      0.667263  0.621465  Jeff Bezos Wealth
# ..          ...            ...           ...       ...                ...
# 19           19       0.542988      0.664594  0.630246     Total Averages
# 20           20       0.544187      0.665052  0.624762     Total Averages
# 21           21       0.544271      0.664725  0.621667     Total Averages
# 22           22       0.543326      0.663744  0.616653     Total Averages
# 23           23       0.540523      0.660540  0.612899     Total Averages
#
# [120 rows x 5 columns]
